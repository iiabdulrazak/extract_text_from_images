# %%
import pandas as pd
from extractingCode import df

# %%
df.head(20)
# Out:
#                                            img  \
# 0                                  13215-1.jpg
# 1                      hqdefault18-310x165.jpg
# 2         7a2cd625b3209fe65ab4f332bdddb1e3.jpg
# 3                       img_1418379759_827.jpg
# 4                       img_1386287359_597.jpg
# 5                              13443931142.jpg
# 6                       16093E444F24BD2E1203AD
# 7                                      2-7.jpg
# 8         jWFzQih3Z4nsYousjUIQ50GmYJXaSoiuTnDy
# 9                              hijab-islam.png
# 10                                       9.jpg
# 11                                   947-9.jpg
# 12                   2947891339_75854ca9b6.jpg
# 13                                    55-2.jpg
# 14                    shof_0485242f00dff66.jpg
# 15  %25D9%2585%25D8%25B1%25D8%25A7%25D8%-2.jpg
# 16              rectangle-shutter-940x1207.png
# 17                            20160803-937.jpg
# 18                                     904.png
# ...
